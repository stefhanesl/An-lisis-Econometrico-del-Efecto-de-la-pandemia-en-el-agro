# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/My Drive/Colab Notebooks/capitulo-2/02-archivos-id-unicos/'
# Out:
# /content/drive/My Drive/Colab Notebooks/capitulo-2/02-archivos-id-unicos

# %%
import os
import numpy as np
import pandas as pd

# %%
nuevo = pd.read_csv('cp-cacao-aroma-fino.csv')
viejo = pd.read_csv('cp-cacao-aroma-fino-viejo.csv')

# %%
nuevo
# Out:
#          Identificador  cg_k100  ...   cp_prod  cp_cantidad_npk_fq
# 0    12065104000040018        1  ...  1.818182                 0.0
# 1    12045102077630016        0  ...  0.000000                 0.0
# 2    12065104000040011        1  ...  0.545455                 0.0
# 3    12065104000030006        1  ...  0.363636                 0.0
# 4     9195102045040009        1  ...  0.136364                50.0
# ..                 ...      ...  ...       ...                 ...
# 813  22035404000460012        0  ...  0.000000                 0.0
# 814  12035001020530001        0  ...  0.181818                 0.0
# 815   9105003010210008        0  ...  0.545455                 0.0
# 816   9105003010210016        1  ...  0.363636                 0.0
# 817   9105003010210015        1  ...  0.681818                 0.0
#
# [818 rows x 19 columns]

# %%
viejo
# Out:
#          Identificador  cg_k100  ...  tratamiento_ventas_demanda   cp_prod
# 0    12065104000040018        1  ...                         0.0  1.818182
# 1    12045102077630016        0  ...                         1.0  0.000000
# 2    12065104000040011        1  ...                         0.0  0.545455
# 3    12065104000030006        1  ...                         0.0  0.363636
# 4     9195102045040009        1  ...                         0.0  0.136364
# ..                 ...      ...  ...                         ...       ...
# 813  22035404000460012        0  ...                         0.0  0.000000
# 814  12035001020530001        0  ...                         0.0  0.181818
# 815   9105003010210008        0  ...                         0.0  0.545455
# 816   9105003010210016        1  ...                         0.0  0.363636
# 817   9105003010210015        1  ...                         0.0  0.681818
#
# [818 rows x 18 columns]

# %%
nuevo[nuevo['Identificador'] == 9195102045040009]
# Out:
#       Identificador  cg_k100  ...   cp_prod  cp_cantidad_npk_fq
# 4  9195102045040009        1  ...  0.136364                50.0
#
# [1 rows x 19 columns]

# %%
viejo[viejo['Identificador'] == 9195102045040009]
# Out:
#       Identificador  cg_k100  ...  tratamiento_ventas_demanda   cp_prod
# 4  9195102045040009        1  ...                         0.0  0.136364
#
# [1 rows x 18 columns]
