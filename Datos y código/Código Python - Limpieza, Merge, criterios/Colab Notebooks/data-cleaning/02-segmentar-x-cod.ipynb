# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/My Drive/Colab Notebooks/data-cleaning'
# Out:
# /content/drive/My Drive/Colab Notebooks/data-cleaning

# %%
import os
import numpy as np
import pandas as pd

# %%
path = os.getcwd()
archivos = os.listdir(path + '/02-limpios')
archivos
# Out:
# ['datos-covid.csv',
#  'datos-transitorios.csv',
#  'datos-empleo.csv',
#  'datos-generales.csv',
#  'datos-permanentes.csv']

# %% [markdown]
# # **Cultivos transitorios**

# %%
df_tran = pd.read_csv('02-limpios/' + archivos[1])
df_tran
# Out:
#            Identificador  ual_prov  ...  ct_nuevacondicion  fact_exp_fin
# 0       1015101086210001         1  ...                  1     51.133616
# 1       1015101086210002         1  ...                  0     33.190534
# 2       1015101086210002         1  ...                  0     33.190534
# 3       1015101086210002         1  ...                  1     38.635138
# 4       1015101086210003         1  ...                  1     39.534297
# ...                  ...       ...  ...                ...           ...
# 15534  24015504000390011        24  ...                  1     25.404548
# 15535  24015504000390012        24  ...                  1     22.014178
# 15536  24015504000550003        24  ...                  1      4.665557
# 15537  24015504000550003        24  ...                  1     15.353735
# 15538  24015504000550003        24  ...                  1      4.789524
#
# [15539 rows x 120 columns]

# %%
# 507 -> arroz | 548 -> maiz

# %% [markdown]
# **Filtro arroz**

# %%
arroz = df_tran[df_tran['rc_clacul'] == 507]
arroz
# Out:
#            Identificador  ual_prov  ...  ct_nuevacondicion  fact_exp_fin
# 2753    3045251000993377         3  ...                  1      1.000000
# 2754    3045251000993377         3  ...                  1      1.000000
# 2755    3045251000993417         3  ...                  1      1.000000
# 2756    3045251000993417         3  ...                  1      1.000000
# 4199    5035102003300002         5  ...                  1     30.799574
# ...                  ...       ...  ...                ...           ...
# 15266  21045502032150001        21  ...                  1    113.854909
# 15276  21065202007630003        21  ...                  1     59.290299
# 15288  21075003020550006        21  ...                  1     52.340054
# 15289  21075003020550007        21  ...                  1     97.158622
# 15388  22045501001440002        22  ...                  1     25.922666
#
# [1527 rows x 120 columns]

# %%
arroz['Identificador'].nunique()
# Out:
# 1003

# %%
arroz['Identificador'].duplicated().sum()
# Out:
# 524

# %%
arroz['Identificador'][arroz['Identificador'].duplicated()]
# Out:
# 2754      3045251000993377
# 2756      3045251000993417
# 7262      7025602017970001
# 7264      7025602017970002
# 7266      7025602017970003
#                ...
# 11544    12085102119490012
# 11552    12085102119490018
# 12478    13145302189440017
# 12482    13145302189440019
# 12713    13165102238520012
# Name: Identificador, Length: 524, dtype: int64

# %%
arroz[arroz['Identificador'] == 3045251000993377]
# Out:
#          Identificador  ual_prov  ...  ct_nuevacondicion  fact_exp_fin
# 2753  3045251000993377         3  ...                  1           1.0
# 2754  3045251000993377         3  ...                  1           1.0
#
# [2 rows x 120 columns]

# %%
arroz[arroz['Identificador'] == 13165102238520012]
# Out:
#            Identificador  ual_prov  ...  ct_nuevacondicion  fact_exp_fin
# 12711  13165102238520012        13  ...                  1     15.436513
# 12713  13165102238520012        13  ...                  1     18.719666
#
# [2 rows x 120 columns]

# %%
arroz.to_csv('ct-arroz.csv', sep=',', encoding='utf-8', index=False)

# %% [markdown]
# <hr/>

# %% [markdown]
# **Filtro Maiz**

# %%
maiz = df_tran[df_tran['rc_clacul'] == 548]
maiz
# Out:
#            Identificador  ual_prov  ...  ct_nuevacondicion  fact_exp_fin
# 640     1025001182830001         1  ...                  1     45.436784
# 645     1025001182830007         1  ...                  1    396.115841
# 647     1025001191620001         1  ...                  1     21.125970
# 648     1025001191620002         1  ...                  0     17.972687
# 661     1025101216290001         1  ...                  1     30.090074
# ...                  ...       ...  ...                ...           ...
# 15534  24015504000390011        24  ...                  1     25.404548
# 15535  24015504000390012        24  ...                  1     22.014178
# 15536  24015504000550003        24  ...                  1      4.665557
# 15537  24015504000550003        24  ...                  1     15.353735
# 15538  24015504000550003        24  ...                  1      4.789524
#
# [2290 rows x 120 columns]

# %%
maiz['Identificador'].nunique()
# Out:
# 1808

# %%
maiz['Identificador'].duplicated().sum()
# Out:
# 482

# %%
maiz['Identificador'][maiz['Identificador'].duplicated()]
# Out:
# 1153      1055301052980002
# 1156      1055301052980004
# 1160      1055301052980004
# 1161      1055301052980004
# 1171      1055301052980005
#                ...
# 15525    24015504000390003
# 15527    24015504000390004
# 15528    24015504000390004
# 15537    24015504000550003
# 15538    24015504000550003
# Name: Identificador, Length: 482, dtype: int64

# %%
maiz[maiz['Identificador'] == 1055301052980004]
# Out:
#          Identificador  ual_prov  ...  ct_nuevacondicion  fact_exp_fin
# 1154  1055301052980004         1  ...                  0     15.127896
# 1156  1055301052980004         1  ...                  0     51.741565
# 1160  1055301052980004         1  ...                  1     94.450350
# 1161  1055301052980004         1  ...                  1     53.065771
#
# [4 rows x 120 columns]

# %%
maiz[maiz['Identificador'] == 24015504000390003]
# Out:
#            Identificador  ual_prov  ...  ct_nuevacondicion  fact_exp_fin
# 15524  24015504000390003        24  ...                  1     10.258439
# 15525  24015504000390003        24  ...                  1      9.172684
#
# [2 rows x 120 columns]

# %%
maiz.to_csv('ct-maiz.csv', sep=',', encoding='utf-8', index=False)

# %% [markdown]
# <hr/>

# %% [markdown]
# # **Cultivos permanentes**

# %%
df_perm = pd.read_csv('02-limpios/' + archivos[-1])
df_perm
# Out:
#            Identificador  ual_prov  ...  nuevacondicion  fact_exp_fin
# 0       1015601063680009         1  ...               1     76.345991
# 1       1015701077200001         1  ...               1     65.241394
# 2       1015702000130001         1  ...               1      1.292061
# 3       1015702000130002         1  ...               1      6.138338
# 4       1015702000130002         1  ...               1     16.035685
# ...                  ...       ...  ...             ...           ...
# 13083  24015503001310014        24  ...               1      9.072603
# 13084  24015504000390002        24  ...               1     13.978423
# 13085  24015504000390012        24  ...               1     19.512794
# 13086  24015504000550003        24  ...               1      5.913621
# 13087  24015504000550003        24  ...               1      3.409482
#
# [13088 rows x 118 columns]

# %%
# 411 -> cacao ramilla | 483 -> cacao fino aroma | 419 -> caña de azúcar | 407 -> banano

# %% [markdown]
# **Filtro Cacao Ramilla**

# %%
cacao_ramilla = df_perm[df_perm['rc_clacul'] == 411]
cacao_ramilla
# Out:
#            Identificador  ual_prov  ...  nuevacondicion  fact_exp_fin
# 194     1155061000992567         1  ...               1      1.000000
# 237     2016001002550001         2  ...               1     12.183585
# 238     2016001002550002         2  ...               0     27.765117
# 240     2016001002550002         2  ...               0      3.159007
# 242     2016001002550003         2  ...               0     15.166779
# ...                  ...       ...  ...             ...           ...
# 13073  24015503001310005        24  ...               1     17.961542
# 13080  24015503001310010        24  ...               1     10.721820
# 13081  24015503001310013        24  ...               1     15.188160
# 13083  24015503001310014        24  ...               1      9.072603
# 13087  24015504000550003        24  ...               1      3.409482
#
# [2456 rows x 118 columns]

# %%
cacao_ramilla['Identificador'].nunique()
# Out:
# 2137

# %%
cacao_ramilla['Identificador'].duplicated().sum()
# Out:
# 319

# %%
cacao_ramilla['Identificador'][cacao_ramilla['Identificador'].duplicated()]
# Out:
# 240       2016001002550002
# 296       2016003000450009
# 310       2016003000450018
# 408       2045004000170001
# 414       2045004000170004
#                ...
# 12667    23015403000380011
# 12703    23015501001510004
# 12722    23015501004750004
# 12799    23015503000210003
# 12952    23025102003970009
# Name: Identificador, Length: 319, dtype: int64

# %%
cacao_ramilla[cacao_ramilla['Identificador'] == 2016003000450018]
# Out:
#         Identificador  ual_prov  ...  nuevacondicion  fact_exp_fin
# 308  2016003000450018         2  ...               0     17.756573
# 310  2016003000450018         2  ...               1     38.270637
#
# [2 rows x 118 columns]

# %%
cacao_ramilla[cacao_ramilla['Identificador'] == 23015503000210003]
# Out:
#            Identificador  ual_prov  ...  nuevacondicion  fact_exp_fin
# 12798  23015503000210003        23  ...               1     32.600186
# 12799  23015503000210003        23  ...               1     28.819989
#
# [2 rows x 118 columns]

# %%
cacao_ramilla.to_csv('cp-cacao-ramilla.csv', sep=',', encoding='utf-8', index=False)

# %% [markdown]
# <hr/>

# %% [markdown]
# **Filtro Cacao Aroma Fino**

# %%
cacao_aroma_fino = df_perm[df_perm['rc_clacul'] == 483]
cacao_aroma_fino
# Out:
#            Identificador  ual_prov  ...  nuevacondicion  fact_exp_fin
# 257     2016001013450001         2  ...               0     67.682960
# 263     2016002000280001         2  ...               0     10.794134
# 265     2016002000280002         2  ...               0     12.765506
# 539     2065001088550001         2  ...               1      9.365178
# 566     2065001094930005         2  ...               1     12.102929
# ...                  ...       ...  ...             ...           ...
# 12794  23015503000210002        23  ...               1      8.281762
# 12796  23015503000210002        23  ...               1     32.084129
# 12812  23015503000210014        23  ...               1     37.944333
# 12857  23015701122220003        23  ...               1     13.155702
# 13082  24015503001310013        24  ...               1     23.283237
#
# [954 rows x 118 columns]

# %%
cacao_aroma_fino['Identificador'].nunique()
# Out:
# 819

# %%
cacao_aroma_fino['Identificador'].duplicated().sum()
# Out:
# 135

# %%
cacao_aroma_fino['Identificador'][cacao_aroma_fino['Identificador'].duplicated()]
# Out:
# 1997      8015902078810002
# 2099      8025104001250014
# 2102      8025104001250016
# 2147      8025902105330002
# 2605      8045302119920002
#                ...
# 11116    19065002003000007
# 11453    21045002044560011
# 11856    22035003001620005
# 11887    22035302007530006
# 12796    23015503000210002
# Name: Identificador, Length: 135, dtype: int64

# %%
cacao_aroma_fino[cacao_aroma_fino['Identificador'] == 8025104001250014]
# Out:
#          Identificador  ual_prov  ...  nuevacondicion  fact_exp_fin
# 2098  8025104001250014         8  ...               1     22.019874
# 2099  8025104001250014         8  ...               1     37.087903
#
# [2 rows x 118 columns]

# %%
cacao_aroma_fino[cacao_aroma_fino['Identificador'] == 8045302119920002]
# Out:
#          Identificador  ual_prov  ...  nuevacondicion  fact_exp_fin
# 2604  8045302119920002         8  ...               1     70.647108
# 2605  8045302119920002         8  ...               1     82.556176
#
# [2 rows x 118 columns]

# %%
cacao_aroma_fino.to_csv('cp-cacao-aroma-fino.csv', sep=',', encoding='utf-8', index=False)

# %% [markdown]
# <hr/>

# %% [markdown]
# **Filtro Caña de azúcar**

# %%
cana_azucar = df_perm[df_perm['rc_clacul'] == 419]
cana_azucar
# Out:
#           Identificador  ual_prov  ...  nuevacondicion  fact_exp_fin
# 852    3045002001400003         3  ...               1      0.000000
# 853    3045002001400003         3  ...               1      0.000000
# 854    3045002001400003         3  ...               1      0.000000
# 855    3045002001400003         3  ...               1      0.000000
# 860    3045002001840001         3  ...               1      0.000000
# ...                 ...       ...  ...             ...           ...
# 9604  14015703007470007        14  ...               1     24.358875
# 9605  14015703007470008        14  ...               1     45.746127
# 9606  14015703007470011        14  ...               1     51.277370
# 9608  14015703007470012        14  ...               1     84.272336
# 9610  14015703007470013        14  ...               1     79.620343
#
# [241 rows x 118 columns]

# %%
cana_azucar['Identificador'].nunique()
# Out:
# 171

# %%
cana_azucar['Identificador'].duplicated().sum()
# Out:
# 70

# %%
cana_azucar['Identificador'][cana_azucar['Identificador'].duplicated()]
# Out:
# 853      3045002001400003
# 854      3045002001400003
# 855      3045002001400003
# 861      3045002001840001
# 862      3045002001840001
#               ...
# 5288    11035001098090001
# 5289    11035001098090001
# 5290    11035001098090001
# 5291    11035001098090001
# 5292    11035001098090001
# Name: Identificador, Length: 70, dtype: int64

# %%
cana_azucar[cana_azucar['Identificador'] == 5025002000850004]
# Out:
# Empty DataFrame
# ...

# %%
cana_azucar[cana_azucar['Identificador'] == 24015003001590001]
# Out:
# Empty DataFrame
# ...

# %%
cana_azucar.to_csv('cp-cana-azucar.csv', sep=',', encoding='utf-8', index=False)

# %% [markdown]
# <hr/>

# %% [markdown]
# **Filtro Banano**

# %%
banano = df_perm[df_perm['rc_clacul'] == 407]
banano
# Out:
#            Identificador  ual_prov  ...  nuevacondicion  fact_exp_fin
# 44      1025101223210002         1  ...               1     60.293343
# 113     1065201252140003         1  ...               1     16.248157
# 848     3045002000900001         3  ...               1     34.620923
# 849     3045002000900001         3  ...               1     29.173219
# 850     3045002000900002         3  ...               1      3.273766
# ...                  ...       ...  ...             ...           ...
# 13024  24015003001590001        24  ...               1      0.000000
# 13025  24015003001590001        24  ...               1      0.000000
# 13026  24015003001590001        24  ...               1      0.000000
# 13028  24015003001750002        24  ...               1      7.627751
# 13029  24015052000990162        24  ...               1      1.000000
#
# [477 rows x 118 columns]

# %%
banano['Identificador'].nunique()
# Out:
# 394

# %%
banano['Identificador'].duplicated().sum()
# Out:
# 83

# %%
banano['Identificador'][banano['Identificador'].duplicated()]
# Out:
# 849       3045002000900001
# 1132      5025002000390001
# 1148      5025002000850004
# 1151      5025002000850006
# 1153      5025002000870001
#                ...
# 12974    23025252000990170
# 13012    23025302006310013
# 13024    24015003001590001
# 13025    24015003001590001
# 13026    24015003001590001
# Name: Identificador, Length: 83, dtype: int64

# %%
banano[banano['Identificador'] == 5025002000870001]
# Out:
#          Identificador  ual_prov  ...  nuevacondicion  fact_exp_fin
# 1152  5025002000870001         5  ...               1      6.087515
# 1153  5025002000870001         5  ...               1      6.958356
# 1154  5025002000870001         5  ...               1      4.173092
#
# [3 rows x 118 columns]

# %%
banano[banano['Identificador'] == 23025302006310013]
# Out:
#            Identificador  ual_prov  ...  nuevacondicion  fact_exp_fin
# 13011  23025302006310013        23  ...               1      8.084042
# 13012  23025302006310013        23  ...               1      8.323098
#
# [2 rows x 118 columns]

# %%
banano.to_csv('cp-banano.csv', sep=',', encoding='utf-8', index=False)

# %% [markdown]
# <hr/>
