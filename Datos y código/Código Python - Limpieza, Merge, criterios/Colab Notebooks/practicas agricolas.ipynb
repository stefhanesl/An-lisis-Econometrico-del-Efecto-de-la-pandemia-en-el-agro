# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/My Drive/Colab Notebooks/data-merging'
# !ls
# Out:
# /content/drive/My Drive/Colab Notebooks/data-merging
#  datos-covid.csv	       mapa-procesos.gdoc
#  datos-covid-tratamiento.csv   merging-principales-cultivos
#  datos-empleo.csv	      'practicas agricolas.ipynb'
#  datos-generales.csv	       working.ipynb
#  datos-principales.csv

# %%
import os
import numpy as np
import pandas as pd

# %%
def convertir_columna_categorica(df):
  for columna in df.columns:
    if df[columna].nunique() == 2:
      df[columna] = pd.Categorical(df[columna])
  return df

# %%
pagr = pd.read_csv('ambnac2020.csv', encoding = "ISO-8859-1")
pagr.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-20ee0a68ecd5> in <module>()
# ----> 1 pagr = pd.read_csv('ambnac2020.csv', encoding = "ISO-8859-1")
#       2 pagr.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...

# %%
pagr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26526 entries, 0 to 26525
# Columns: 153 entries, ual_prov to plag_observa
# dtypes: int64(27), object(126)
# memory usage: 31.0+ MB

# %%
pagr.columns.nunique()
# Out:
# 153

# %%
union = ['ual_prov', 'ual_cant',	'ual_parr',	'ual_estr',	'ual_segm',	'al_ncues']
pagr['ual_prov'].dtype
# Out:
# dtype('int64')

# %%
columnas = []
i = 0
for col in union:
  str(col)
  columnas.append(col)
  i+=1
type(union[0])
# Out:
# str

# %% [markdown]
# PRUEBA DE CODIGO

# %%
matriz = pd.DataFrame([['2','4','7'],
          ['3','8','0']], columns=['A','B','C'])

# %%
matriz
# Out:
#    A  B  C
# 0  2  4  7
# 1  3  8  0

# %%
#'ual_prov', 'ual_cant',	'ual_parr',	'ual_estr',	'ual_segm',	'al_ncues'

# %%
def custom_sum(row):
    return row.sum()
matriz['D'] = matriz[['A', 'B']].apply(custom_sum, axis=1)

# %%
matriz
# Out:
#    A  B  C   D
# 0  2  4  7  24
# 1  3  8  0  38

# %%
for i in matriz.values:
  if len(i) == 1:

# %%
for col in list(matriz.columns):
  matriz[col] = matriz[col].map('0{}'.format)

# %%
matriz
# Out:
#     A   B   C     D
# 0  02  04  07  0247
# 1  03  08  00  0380

# %%
for elemento in matriz.iloc[:,:2]:
  print(len(elemento))
# Out:
# 1
# 1

# %%
def agregarCero(df):
  for elemento in df.iloc[:,:6]:
    if (elemento == 'ual_prov' | elemento == 'ual_cant' | elemento ==	'ual_parr'| elemento == 'ual_estr') & (len(elemento) == 1):
      matriz[elemento] = matriz[elemento].map('0{}'.format)
    elif (elemento == 'ual_segm'):
      contador=0
      while (len(elemento) < 5):
        matriz[elemento] = matriz[elemento].map('0{}'.format)
        contador=+1
    elif (elemento == 'al_ncues'):
      cont=0
      while (len(elemento) < 4):
        matriz[elemento] = matriz[elemento].map('0{}'.format)
        cont=+1
    else:
      None
  return True

# %%
cambios = pagr.apply(agregarCero, axis=1)
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-15-87fbcfa2f15c> in <module>()
# ----> 1 cambios = pagr.apply(agregarCero, axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7550             kwds=kwds,
#    7551         )
# -> 7552         return op.get_result()
#    7553
#    7554     def applymap(self, func) -> "DataFrame":
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# --> 185         return self.apply_standard()
#     186
#     187     def apply_empty_result(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply_standard(self)
#     274
#     275     def apply_standard(self):
# --> 276         results, res_index = self.apply_series_generator()
#     277
# ...
